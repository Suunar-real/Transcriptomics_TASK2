# %% [markdown]
# # Проект 2: Анализ мутаций в прокариотическом геноме

# %% [markdown]
# - .SAM (sample alligned map?)- индексирование референсного генома
# - .VCF (variant calling format) - формат для хранения SNP (single nucleotide polymorfism), которые были определены по референсу после выравнивания
# - IGV - программа для визуализации покрытия генома, SNP и т.п.
#
# Изучить механизм эволюции бактерии (E.Coli) в устойчивость к антибиотикам (намек на GEO и KEGG парсинг)

# %% [markdown]
# # Подготовительный этап

# %%
mkdir -p TASK2 && cd TASK2 # Рабочая директория

conda activate biolab # Загрузка окружения

# Подготовка инструментов

conda install -c bioconda vcftools # Для оценки мутаций

conda create -n IGV -c bioconda igv # Подготовка окружения для визуализатора мутаций

# %% [markdown]
# # Содержание окружений

# %%
conda activate biolab && conda list
# Out:
# # packages in environment at /home/suunar/miniforge3/envs/biolab:
# #
# # Name                                   Version          Build                 Channel
# _openmp_mutex                            4.5              20_gnu                conda-forge
# about-time                               4.2.1            pyhd8ed1ab_1          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# abricate                                 1.2.0            h05cac1d_0            bioconda
# alive-progress                           3.3.0            pypi_0                pypi
# alsa-lib                                 1.2.3.2          h166bdaf_0            conda-forge
# anndata                                  0.10.9           pypi_0                pypi
# any2fasta                                0.8.1            hdfd78af_0            bioconda
# aragorn                                  1.2.41           h7b50bb2_5            bioconda
# archspec                                 0.2.5            pyhd8ed1ab_0          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# argtable2                                2.13             hd590300_1004         conda-forge
# aria2                                    1.36.0           h3f1041a_2            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# array-api-compat                         1.11.2           pypi_0                pypi
# asttokens                                3.0.0            pyhd8ed1ab_1          conda-forge
# augustus                                 3.5.0            pl5321heb9362c_5      bioconda
# backports                                1.0              pyhd8ed1ab_5          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# backports.tempfile                       1.0              py_0                  https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# backports.weakref                        1.0.post1        pyhd8ed1ab_1003       https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# bamtools                                 2.5.2            hdcf5f25_5            bioconda
# barrnap                                  0.9              hdfd78af_4            bioconda
# bash                                     5.2.37           h4be8908_0            conda-forge
# bash_kernel                              0.10.0           pyh707e725_0          conda-forge
# bbmap                                    39.26            he5f24ec_0            bioconda
# bcbio-gff                                0.7.1            pyhdfd78af_3          bioconda
# bedtools                                 2.31.1           hf5e1c6e_2            bioconda
# biopython                                1.85             py39h8cd3c5a_1        conda-forge
# black                                    25.11.0          pypi_0                pypi
# blast                                    2.16.0           hc155240_3            bioconda
# blast-legacy                             2.2.26           hf7ff83a_5            bioconda
# boost-cpp                                1.77.0           h312852a_0            conda-forge
# brotli                                   1.2.0            hed03a55_1            conda-forge
# brotli-bin                               1.2.0            hb03c661_1            conda-forge
# brotli-python                            1.0.9            py39h5a03fae_8        conda-forge
# busco                                    6.0.0            pyhdfd78af_2          bioconda
# bwa                                      0.7.18           he4a0461_1            bioconda
# bwa-mem2                                 2.2.1            hd03093a_5            bioconda
# bx-python                                0.13.0           py39hdf45acc_0        bioconda
# bzip2                                    1.0.8            hda65f42_9            conda-forge
# c-ares                                   1.34.6           hb03c661_0            conda-forge
# ca-certificates                          2026.2.25        hbd8a1cb_0            conda-forge
# cairo                                    1.16.0           h6cf1ce9_1008         conda-forge
# cap3                                     10.2011          h779adbc_3            bioconda
# capnproto                                1.0.2            h2b92303_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# cdbtools                                 0.99             hdcf5f25_10           bioconda
# certifi                                  2026.2.25        pypi_0                pypi
# cffi                                     1.17.1           py39h15c3d72_0        conda-forge
# charset-normalizer                       3.4.6            pypi_0                pypi
# circos                                   0.69.9           hdfd78af_0            bioconda
# click                                    8.1.8            pyh707e725_0          conda-forge
# clustalo                                 1.2.4            h503566f_10           bioconda
# clustalw                                 2.1              h9948957_12           bioconda
# colorama                                 0.4.6            pyhd8ed1ab_1          conda-forge
# coloredlogs                              15.0.1           pyhd8ed1ab_4          conda-forge
# colormath                                3.0.0            pyhd8ed1ab_4          conda-forge
# comm                                     0.2.3            pyhe01879c_0          conda-forge
# contourpy                                1.3.0            py39h74842e3_2        conda-forge
# coverage                                 7.10.7           pypi_0                pypi
# curl                                     8.8.0            he654da7_1            conda-forge
# cycler                                   0.12.1           pyhd8ed1ab_1          conda-forge
# debugpy                                  1.8.16           py39haef64b4_0        conda-forge
# decorator                                5.2.1            pyhd8ed1ab_0          conda-forge
# dendropy                                 5.0.8            pyhdfd78af_1          bioconda
# diamond                                  2.1.10           h43eeafb_2            bioconda
# dnaapler                                 1.3.0            pyhdfd78af_0          bioconda
# dnspython                                2.7.0            pyhff2d567_1          conda-forge
# entrez-direct                            22.4             he881be0_0            bioconda
# exceptiongroup                           1.3.1            pypi_0                pypi
# executing                                2.2.0            pyhd8ed1ab_0          conda-forge
# executor                                 23.2             pyhd8ed1ab_1          conda-forge
# expat                                    2.7.4            hecca717_0            conda-forge
# fasteners                                0.19             pyhd8ed1ab_1          conda-forge
# fastp                                    1.1.0            heae3180_0            bioconda
# fastq-dl                                 3.0.1            pyhdfd78af_0          bioconda
# fastqc                                   0.12.1           hdfd78af_0            bioconda
# fasttree                                 2.2.0            h7b50bb2_1            bioconda
# filetype                                 1.2.0            pyhd8ed1ab_0          conda-forge
# font-ttf-dejavu-sans-mono                2.37             hab24e00_0            conda-forge
# font-ttf-inconsolata                     3.000            h77eed37_0            conda-forge
# font-ttf-source-code-pro                 2.038            h77eed37_0            conda-forge
# font-ttf-ubuntu                          0.83             h77eed37_3            conda-forge
# fontconfig                               2.14.2           h14ed4e7_0            conda-forge
# fonts-conda-ecosystem                    1                0                     conda-forge
# fonts-conda-forge                        1                hc364b38_1            conda-forge
# fonttools                                4.59.1           py39heb7d2ae_0        conda-forge
# freetype                                 2.12.1           h267a509_2            conda-forge
# future                                   1.0.0            pyhd8ed1ab_2          conda-forge
# gawk                                     5.3.1            hcd3d067_0            conda-forge
# genbank                                  0.121            py39hbcbf7aa_1        bioconda
# giflib                                   5.2.2            hd590300_0            conda-forge
# glimmerhmm                               3.0.4            pl5321h503566f_10     bioconda
# gmp                                      6.3.0            hac33072_2            conda-forge
# gnutls                                   3.8.11           h18acefa_1            conda-forge
# grapheme                                 0.6.0            pyhd8ed1ab_1          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# graphemeu                                0.7.2            pypi_0                pypi
# graphite2                                1.3.14           hecca717_2            conda-forge
# gsl                                      2.7              he838d99_0            conda-forge
# gzip                                     1.14             hb9d3cd8_0            conda-forge
# h2                                       4.2.0            pyhd8ed1ab_0          conda-forge
# h5py                                     3.14.0           pypi_0                pypi
# harfbuzz                                 2.9.1            h83ec7ef_1            conda-forge
# hmmer                                    3.4              hb6cb901_4            bioconda
# hpack                                    4.1.0            pyhd8ed1ab_0          conda-forge
# htslib                                   1.21             h5efdd21_0            bioconda
# humanfriendly                            10.0             pyh707e725_8          conda-forge
# humanize                                 4.12.3           pyhd8ed1ab_0          conda-forge
# hyperframe                               6.1.0            pyhd8ed1ab_0          conda-forge
# icu                                      68.2             h9c3ff4c_0            conda-forge
# idna                                     3.11             pypi_0                pypi
# importlib-metadata                       8.7.1            pypi_0                pypi
# importlib-resources                      6.5.2            pyhd8ed1ab_0          conda-forge
# importlib_resources                      6.5.2            pyhd8ed1ab_0          conda-forge
# infernal                                 1.1.5            pl5321h7b50bb2_4      bioconda
# iniconfig                                2.1.0            pypi_0                pypi
# ipykernel                                6.30.1           pyh82676e8_0          conda-forge
# ipython                                  8.18.1           pyh707e725_3          conda-forge
# isa-l                                    2.31.1           hb9d3cd8_1            conda-forge
# isort                                    6.1.0            pypi_0                pypi
# jedi                                     0.19.2           pyhd8ed1ab_1          conda-forge
# jinja2                                   3.1.6            pyhd8ed1ab_0          conda-forge
# joblib                                   1.5.1            pyhd8ed1ab_0          conda-forge
# jpeg                                     9e               h0b41bf4_3            conda-forge
# jupyter_client                           8.6.3            pyhd8ed1ab_1          conda-forge
# jupyter_core                             5.8.1            pyh31011fe_0          conda-forge
# k8                                       0.2.5            hdcf5f25_4            bioconda
# keyutils                                 1.6.3            hb9d3cd8_0            conda-forge
# kiwisolver                               1.4.7            py39h74842e3_0        conda-forge
# krb5                                     1.21.3           h659f571_0            conda-forge
# lcms2                                    2.12             hddcbb42_0            conda-forge
# ld_impl_linux-64                         2.45.1           bootstrap_ha15bf96_1  conda-forge
# libasprintf                              0.25.1           h3f43e3d_1            conda-forge
# libblas                                  3.11.0           5_h4a7cf45_openblas   conda-forge
# libbrotlicommon                          1.2.0            hb03c661_1            conda-forge
# libbrotlidec                             1.2.0            hb03c661_1            conda-forge
# libbrotlienc                             1.2.0            hb03c661_1            conda-forge
# libcblas                                 3.11.0           5_h0358290_openblas   conda-forge
# libcurl                                  8.8.0            hca28451_1            conda-forge
# libdb                                    6.2.32           h9c3ff4c_0            conda-forge
# libdeflate                               1.22             hb9d3cd8_0            conda-forge
# libedit                                  3.1.20250104     pl5321h7949ede_0      conda-forge
# libev                                    4.33             hd590300_2            conda-forge
# libexpat                                 2.7.4            hecca717_0            conda-forge
# libffi                                   3.5.2            h3435931_0            conda-forge
# libgcc                                   15.2.0           he0feb66_18           conda-forge
# libgcc-ng                                15.2.0           h69a702a_18           conda-forge
# libgd                                    2.3.2            h78a0170_0            conda-forge
# libgettextpo                             0.25.1           h3f43e3d_1            conda-forge
# libgfortran                              15.2.0           h69a702a_18           conda-forge
# libgfortran-ng                           15.2.0           h69a702a_18           conda-forge
# libgfortran5                             15.2.0           h68bc16d_18           conda-forge
# libglib                                  2.80.2           hf974151_0            conda-forge
# libgomp                                  15.2.0           he0feb66_18           conda-forge
# libiconv                                 1.18             h3b78370_2            conda-forge
# libidn11                                 1.34             h1cef754_0            conda-forge
# libidn2                                  2.3.8            hfac485b_1            conda-forge
# liblapack                                3.11.0           5_h47877c9_openblas   conda-forge
# liblzma                                  5.8.2            hb03c661_0            conda-forge
# liblzma-devel                            5.8.2            hb03c661_0            conda-forge
# libnghttp2                               1.58.0           h47da74e_1            conda-forge
# libnsl                                   2.0.1            hb9d3cd8_1            conda-forge
# libopenblas                              0.3.30           pthreads_h94d23a6_4   conda-forge
# libopenssl-static                        3.6.1            hb03c661_1            conda-forge
# libpng                                   1.6.43           h2797004_0            conda-forge
# libsodium                                1.0.20           h4ab18f5_0            conda-forge
# libsqlite                                3.46.0           hde9e2c9_0            conda-forge
# libssh2                                  1.11.0           h0841786_0            conda-forge
# libstdcxx                                15.2.0           h934c35e_18           conda-forge
# libstdcxx-ng                             15.2.0           hdf11a46_18           conda-forge
# libtasn1                                 4.21.0           hb03c661_0            conda-forge
# libtiff                                  4.2.0            hf544144_3            conda-forge
# libunistring                             0.9.10           h7f98852_0            conda-forge
# libuuid                                  2.41.3           h5347b49_0            conda-forge
# libwebp                                  1.2.0            h3452ae3_0            conda-forge
# libwebp-base                             1.2.0            h7f98852_2            conda-forge
# libxcb                                   1.17.0           h8a09558_0            conda-forge
# libxcrypt                                4.4.36           hd590300_1            conda-forge
# libxml2                                  2.9.12           h72842e0_0            conda-forge
# libxslt                                  1.1.33           h15afd5d_2            conda-forge
# libzlib                                  1.2.13           h4ab18f5_6            conda-forge
# loguru                                   0.7.3            pyh707e725_0          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# lp_solve                                 5.5.2.11         hd590300_0            conda-forge
# lxml                                     4.8.0            py39hb9d737c_2        conda-forge
# lzstring                                 1.0.4            pyhd8ed1ab_1003       conda-forge
# mafft                                    7.526            h4bc722e_0            conda-forge
# markdown                                 3.8.2            pyhd8ed1ab_0          conda-forge
# markdown-it-py                           3.0.0            pyhd8ed1ab_1          conda-forge
# markupsafe                               3.0.2            py39h9399b63_1        conda-forge
# mash                                     2.3              hc74b729_7            bioconda
# matplotlib-base                          3.9.4            py39h16632d1_0        conda-forge
# matplotlib-inline                        0.1.7            pyhd8ed1ab_1          conda-forge
# mdurl                                    0.1.2            pyhd8ed1ab_1          conda-forge
# metaeuk                                  7.bba0d80        pl5321h6a68c12_1      bioconda
# metis                                    5.1.0            hd0bcaf9_1007         conda-forge
# minced                                   0.4.2            hdfd78af_1            bioconda
# miniasm                                  0.3              he4a0461_3            bioconda
# minimap2                                 2.28             he4a0461_3            bioconda
# miniprot                                 0.13             he4a0461_1            bioconda
# mmseqs2                                  16.747c6         pl5321h6a68c12_0      bioconda
# mpfr                                     4.2.1            h90cbb55_3            conda-forge
# mpi                                      1.0              openmpi               conda-forge
# multiqc                                  1.19             pyhdfd78af_0          bioconda
# munkres                                  1.1.4            pyhd8ed1ab_1          conda-forge
# muscle                                   3.8.1551         h9948957_9            bioconda
# mypy_extensions                          1.1.0            pyha770c72_0          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# mysql-connector-c                        6.1.11           h659d440_1008         conda-forge
# natsort                                  8.4.0            pypi_0                pypi
# ncbi-vdb                                 3.3.0            h9948957_0            bioconda
# ncurses                                  6.5              h2d0b736_3            conda-forge
# nest-asyncio                             1.6.0            pyhd8ed1ab_1          conda-forge
# nettle                                   3.10.1           h4a9d5aa_0            conda-forge
# networkx                                 3.2.1            pyhd8ed1ab_0          conda-forge
# numpy                                    2.0.2            py39h9cb892a_1        conda-forge
# olefile                                  0.47             pyhd8ed1ab_1          conda-forge
# openjdk                                  11.0.9.1         h5cc2fde_1            conda-forge
# openjpeg                                 2.4.0            hb52868f_1            conda-forge
# openmpi                                  4.1.6            hc5af2df_101          conda-forge
# openssl                                  3.6.1            h35e630c_1            conda-forge
# ossuuid                                  1.6.2            h5888daf_1001         conda-forge
# p11-kit                                  0.26.2           h3435931_0            conda-forge
# packaging                                26.0             pyhcf101f3_0          conda-forge
# paml                                     4.10.10          h7b50bb2_0            bioconda
# pandas                                   2.3.3            pypi_0                pypi
# parallel                                 20260122         ha770c72_0            conda-forge
# parso                                    0.8.4            pyhd8ed1ab_1          conda-forge
# pasta                                    1.9.3            py39h640ec12_0        bioconda
# pathspec                                 1.0.4            pypi_0                pypi
# patsy                                    1.0.1            pyhd8ed1ab_1          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# pcre                                     8.45             h9c3ff4c_0            conda-forge
# pcre2                                    10.43            hcad00b1_0            conda-forge
# perl                                     5.32.1           7_hd590300_perl5      conda-forge
# perl-algorithm-diff                      1.201            pl5321hd8ed1ab_0      conda-forge
# perl-alien-build                         2.48             pl5321hec16e2b_0      bioconda
# perl-alien-libxml2                       0.17             pl5321hec16e2b_0      bioconda
# perl-app-cpanminus                       1.7048           pl5321hd8ed1ab_0      conda-forge
# perl-archive-tar                         3.04             pl5321hdfd78af_0      bioconda
# perl-b-cow                               0.007            pl5321hb9d3cd8_1      conda-forge
# perl-base                                2.23             pl5321hd8ed1ab_0      conda-forge
# perl-bio-asn1-entrezgene                 1.73             pl5321hdfd78af_3      bioconda
# perl-bio-coordinate                      1.007001         pl5321hdfd78af_3      bioconda
# perl-bio-featureio                       1.6.905          pl5321hdfd78af_4      bioconda
# perl-bio-samtools                        1.43             pl5321he4a0461_4      bioconda
# perl-bio-searchio-hmmer                  1.7.3            pl5321hdfd78af_0      bioconda
# perl-bio-tools-phylo-paml                1.7.3            pl5321hdfd78af_3      bioconda
# perl-bio-tools-run-alignment-clustalw    1.7.4            pl5321hdfd78af_3      bioconda
# perl-bio-tools-run-alignment-tcoffee     1.7.4            pl5321hdfd78af_5      bioconda
# perl-bioperl                             1.7.8            hdfd78af_1            bioconda
# perl-bioperl-core                        1.7.8            pl5321hdfd78af_1      bioconda
# perl-bioperl-run                         1.007003         pl5321hdfd78af_0      bioconda
# perl-business-isbn                       3.007            pl5321hd8ed1ab_0      conda-forge
# perl-business-isbn-data                  20210112.006     pl5321hd8ed1ab_0      conda-forge
# perl-capture-tiny                        0.48             pl5321ha770c72_1      conda-forge
# perl-carp                                1.50             pl5321hd8ed1ab_0      conda-forge
# perl-class-data-inheritable              0.09             pl5321ha770c72_0      conda-forge
# perl-class-method-modifiers              2.13             pl5321ha770c72_0      conda-forge
# perl-clone                               0.46             pl5321hb9d3cd8_1      conda-forge
# perl-common-sense                        3.75             pl5321hd8ed1ab_0      conda-forge
# perl-compress-raw-bzip2                  2.214            pl5321hda65f42_0      conda-forge
# perl-compress-raw-zlib                   2.214            pl5321h4dac143_0      conda-forge
# perl-config-general                      2.67             pl5321hdfd78af_0      bioconda
# perl-constant                            1.33             pl5321hd8ed1ab_0      conda-forge
# perl-data-dump                           1.25             pl5321h7b50bb2_2      bioconda
# perl-data-dumper                         2.183            pl5321hb9d3cd8_1      conda-forge
# perl-db_file                             1.858            pl5321hb9d3cd8_0      conda-forge
# perl-dbi                                 1.647            pl5321hb03c661_0      conda-forge
# perl-devel-stacktrace                    2.04             pl5321h296ab09_0      conda-forge
# perl-digest-hmac                         1.05             pl5321hdfd78af_0      bioconda
# perl-digest-md5                          2.59             pl5321hb9d3cd8_3      conda-forge
# perl-digest-perl-md5                     1.91             pl5321hdfd78af_0      bioconda
# perl-encode                              3.21             pl5321hb9d3cd8_1      conda-forge
# perl-encode-locale                       1.05             pl5321hdfd78af_7      bioconda
# perl-exception-class                     1.45             pl5321ha770c72_0      conda-forge
# perl-exporter                            5.74             pl5321hd8ed1ab_0      conda-forge
# perl-exporter-tiny                       1.002002         pl5321hd8ed1ab_0      conda-forge
# perl-extutils-config                     0.008            pl5321ha770c72_0      conda-forge
# perl-extutils-helpers                    0.026            pl5321ha770c72_0      conda-forge
# perl-extutils-installpaths               0.012            pl5321ha770c72_0      conda-forge
# perl-extutils-makemaker                  7.70             pl5321hd8ed1ab_0      conda-forge
# perl-extutils-pl2bat                     0.005            pl5321ha770c72_0      conda-forge
# perl-ffi-checklib                        0.28             pl5321hdfd78af_0      bioconda
# perl-file-chdir                          0.1011           pl5321hd8ed1ab_0      conda-forge
# perl-file-listing                        6.16             pl5321hdfd78af_0      bioconda
# perl-file-path                           2.18             pl5321hd8ed1ab_0      conda-forge
# perl-file-slurper                        0.014            pl5321hdfd78af_0      bioconda
# perl-file-sort                           1.01             pl5321hdfd78af_3      bioconda
# perl-file-spec                           3.48_01          pl5321hdfd78af_2      bioconda
# perl-file-temp                           0.2304           pl5321hd8ed1ab_0      conda-forge
# perl-file-which                          1.24             pl5321hd8ed1ab_0      conda-forge
# perl-font-ttf                            1.06             pl5321hdfd78af_1      bioconda
# perl-gd                                  2.56             0                     bioconda
# perl-getopt-long                         2.58             pl5321hdfd78af_0      bioconda
# perl-html-parser                         3.81             pl5321h4ac6f70_1      bioconda
# perl-html-tagset                         3.24             pl5321hdfd78af_0      bioconda
# perl-http-cookiejar-lwp                  0.014            pl5321hdfd78af_0      bioconda
# perl-http-cookies                        6.11             pl5321hdfd78af_0      bioconda
# perl-http-daemon                         6.16             pl5321hdfd78af_0      bioconda
# perl-http-date                           6.06             pl5321hdfd78af_0      bioconda
# perl-http-message                        7.01             pl5321hdfd78af_0      bioconda
# perl-http-negotiate                      6.01             pl5321hdfd78af_4      bioconda
# perl-importer                            0.026            pl5321hd8ed1ab_0      conda-forge
# perl-inc-latest                          0.500            pl5321ha770c72_0      conda-forge
# perl-io-compress                         2.216            pl5321h503566f_0      bioconda
# perl-io-html                             1.004            pl5321hdfd78af_0      bioconda
# perl-io-socket-ssl                       2.075            pl5321hd8ed1ab_0      conda-forge
# perl-io-string                           1.08             pl5321hdfd78af_4      bioconda
# perl-io-tty                              1.20             pl5321hb9d3cd8_3      conda-forge
# perl-io-zlib                             1.15             pl5321hdfd78af_1      bioconda
# perl-ipc-run                             20250809.0       pl5321hdfd78af_0      bioconda
# perl-json                                4.10             pl5321hdfd78af_1      bioconda
# perl-json-xs                             4.04             pl5321h9948957_0      bioconda
# perl-libwww-perl                         6.81             pl5321hdfd78af_0      bioconda
# perl-libxml-perl                         0.08             pl5321hdfd78af_3      bioconda
# perl-list-moreutils                      0.430            pl5321hdfd78af_0      bioconda
# perl-list-moreutils-xs                   0.430            pl5321h7b50bb2_5      bioconda
# perl-lwp-mediatypes                      6.04             pl5321hdfd78af_1      bioconda
# perl-lwp-protocol-https                  6.14             pl5321hdfd78af_1      bioconda
# perl-math-bezier                         0.01             pl5321hdfd78af_2      bioconda
# perl-math-round                          0.07             pl5321ha770c72_0      conda-forge
# perl-math-vecstat                        0.08             pl5321hdfd78af_2      bioconda
# perl-mime-base64                         3.16             pl5321hb9d3cd8_3      conda-forge
# perl-module-build                        0.4234           pl5321ha770c72_1      conda-forge
# perl-module-build-tiny                   0.039            pl5321h166bdaf_0      conda-forge
# perl-module-implementation               0.09             pl5321ha770c72_1      conda-forge
# perl-module-load                         0.34             pl5321hdfd78af_0      bioconda
# perl-module-runtime                      0.016            pl5321ha770c72_1      conda-forge
# perl-moo                                 2.005004         pl5321ha770c72_0      conda-forge
# perl-mozilla-ca                          20250602         pl5321hdfd78af_0      bioconda
# perl-net-http                            6.24             pl5321hdfd78af_0      bioconda
# perl-net-ssleay                          1.92             pl5321hf14f497_1      conda-forge
# perl-ntlm                                1.09             pl5321hdfd78af_5      bioconda
# perl-number-format                       1.76             pl5321hd8ed1ab_0      conda-forge
# perl-parallel-forkmanager                2.04             pl5321hdfd78af_0      bioconda
# perl-params-validate                     1.31             pl5321h7b50bb2_5      bioconda
# perl-parent                              0.243            pl5321hd8ed1ab_0      conda-forge
# perl-path-tiny                           0.124            pl5321hd8ed1ab_0      conda-forge
# perl-pathtools                           3.75             pl5321hb9d3cd8_2      conda-forge
# perl-readonly                            2.05             pl5321ha770c72_0      conda-forge
# perl-regexp-common                       2017060201       pl5321hd8ed1ab_0      conda-forge
# perl-role-tiny                           2.002004         pl5321ha770c72_0      conda-forge
# perl-scalar-list-utils                   1.70             pl5321hb03c661_0      conda-forge
# perl-scope-guard                         0.21             pl5321hd8ed1ab_0      conda-forge
# perl-set-intspan                         1.19             pl5321hdfd78af_2      bioconda
# perl-socket                              2.027            pl5321h5c03b87_6      bioconda
# perl-statistics-basic                    1.6611           pl5321hdfd78af_3      bioconda
# perl-storable                            3.15             pl5321hb9d3cd8_2      conda-forge
# perl-sub-info                            0.002            pl5321hd8ed1ab_0      conda-forge
# perl-sub-quote                           2.006006         pl5321ha770c72_0      conda-forge
# perl-sub-uplevel                         0.2800           pl5321hb9d3cd8_0      conda-forge
# perl-svg                                 2.87             pl5321hd8ed1ab_0      conda-forge
# perl-term-table                          0.028            pl5321hdfd78af_0      bioconda
# perl-test-deep                           1.130            pl5321hd8ed1ab_0      conda-forge
# perl-test-differences                    0.72             pl5321ha770c72_0      conda-forge
# perl-test-exception                      0.43             pl5321hd8ed1ab_0      conda-forge
# perl-test-fatal                          0.016            pl5321ha770c72_0      conda-forge
# perl-test-most                           0.38             pl5321hdfd78af_0      bioconda
# perl-test-needs                          0.002009         pl5321hd8ed1ab_0      conda-forge
# perl-test-requiresinternet               0.05             pl5321hdfd78af_1      bioconda
# perl-test-warn                           0.37             pl5321hd8ed1ab_0      conda-forge
# perl-test-warnings                       0.031            pl5321ha770c72_0      conda-forge
# perl-test2-suite                         0.000145         pl5321hdfd78af_0      bioconda
# perl-text-diff                           1.45             pl5321hd8ed1ab_0      conda-forge
# perl-text-format                         0.63             pl5321hdfd78af_0      bioconda
# perl-time-hires                          1.9764           pl5321h7b50bb2_6      bioconda
# perl-time-local                          1.35             pl5321hdfd78af_0      bioconda
# perl-timedate                            2.33             pl5321hdfd78af_2      bioconda
# perl-tree-dag_node                       1.35             pl5321hdfd78af_0      bioconda
# perl-try-tiny                            0.31             pl5321ha770c72_0      conda-forge
# perl-types-serialiser                    1.01             pl5321hdfd78af_0      bioconda
# perl-uri                                 5.34             pl5321ha770c72_0      conda-forge
# perl-url-encode                          0.03             pl5321h9ee0642_1      bioconda
# perl-www-robotrules                      6.02             pl5321hdfd78af_4      bioconda
# perl-xml-dom                             1.46             pl5321hdfd78af_1      bioconda
# perl-xml-dom-xpath                       0.14             pl5321hdfd78af_2      bioconda
# perl-xml-libxml                          2.0207           pl5321h661654b_0      bioconda
# perl-xml-namespacesupport                1.12             pl5321hd8ed1ab_0      conda-forge
# perl-xml-parser                          2.44_01          pl5321hf2e2c51_1004   conda-forge
# perl-xml-regexp                          0.04             pl5321hdfd78af_3      bioconda
# perl-xml-sax                             1.02             pl5321hd8ed1ab_0      conda-forge
# perl-xml-sax-base                        1.09             pl5321hd8ed1ab_0      conda-forge
# perl-xml-sax-expat                       0.51             pl5321hd8ed1ab_0      conda-forge
# perl-xml-simple                          2.25             pl5321hdfd78af_2      bioconda
# perl-xml-xpathengine                     0.14             pl5321hdfd78af_3      bioconda
# perl-yaml                                1.30             pl5321hdfd78af_0      bioconda
# pexpect                                  4.9.0            pyhd8ed1ab_1          conda-forge
# phanotate                                1.6.7            pypi_0                pypi
# pharokka                                 1.9.1            pyhdfd78af_1          bioconda
# pickleshare                              0.7.5            pyhd8ed1ab_1004       conda-forge
# pigz                                     2.8              h2797004_0            conda-forge
# pillow                                   8.2.0            py39hf95b381_1        conda-forge
# pip                                      25.2             pyh8b19718_0          conda-forge
# pixman                                   0.46.4           h54a6638_1            conda-forge
# platformdirs                             4.4.0            pypi_0                pypi
# pluggy                                   1.6.0            pyhf9edf01_1          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# poa                                      2.0              h7b50bb2_6            bioconda
# prank                                    170427           h9948957_1            bioconda
# prodigal                                 2.6.3            h7b50bb2_10           bioconda
# prokka                                   1.15.6           pl5321hdfd78af_0      bioconda
# prompt-toolkit                           3.0.51           pyha770c72_0          conda-forge
# property-manager                         3.0              py_0                  conda-forge
# psutil                                   7.2.2            pypi_0                pypi
# pthread-stubs                            0.4              hb9d3cd8_1002         conda-forge
# ptyprocess                               0.7.0            pyhd8ed1ab_1          conda-forge
# pure_eval                                0.2.3            pyhd8ed1ab_1          conda-forge
# pyaml-env                                1.2.2            pyhd8ed1ab_0          conda-forge
# pycirclize                               1.9.1            pyhd8ed1ab_0          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# pycparser                                2.22             pyh29332c3_1          conda-forge
# pydeseq2                                 0.4.12           pypi_0                pypi
# pygments                                 2.19.2           pyhd8ed1ab_0          conda-forge
# pyhmmer                                  0.12.0           py39hbcbf7aa_0        bioconda
# pymongo                                  4.13.2           py39h818bca1_0        conda-forge
# pyparsing                                3.2.3            pyhe01879c_2          conda-forge
# pyrodigal                                3.7.1            pypi_0                pypi
# pyrodigal-gv                             0.3.2            pyh7e72e81_0          bioconda
# pyrodigal-rv                             0.1.0            pyh7e72e81_0          bioconda
# pysocks                                  1.7.1            pyha55dd90_7          conda-forge
# pysradb                                  2.5.1            pyhdfd78af_0          bioconda
# pytest                                   8.4.2            pypi_0                pypi
# pytest-cov                               7.1.0            pypi_0                pypi
# python                                   3.9.19           h0755675_0_cpython    conda-forge
# python-dateutil                          2.9.0.post0      pyhe01879c_2          conda-forge
# python_abi                               3.9              8_cp39                conda-forge
# pytokens                                 0.4.1            pypi_0                pypi
# pytz                                     2026.1.post1     pypi_0                pypi
# pyyaml                                   6.0.3            pypi_0                pypi
# pyzmq                                    27.0.2           py39haa5fa38_0        conda-forge
# qhull                                    2020.2           h434a139_5            conda-forge
# quast                                    5.3.0            py39pl5321h746d604_1  bioconda
# racon                                    1.5.0            hdcf5f25_5            bioconda
# raxml                                    8.2.13           h7b50bb2_3            bioconda
# readline                                 8.3              h853b02a_0            conda-forge
# requests                                 2.32.5           pyhd8ed1ab_0          conda-forge
# requests-ftp                             0.3.1            pyhd8ed1ab_2          conda-forge
# rich                                     14.1.0           pyhe01879c_0          conda-forge
# rich-click                               1.8.9            pyhd8ed1ab_0          conda-forge
# rpsbproc                                 0.5.0            h6a68c12_1            bioconda
# samtools                                 1.21             h50ea8bc_0            bioconda
# scikit-learn                             1.6.1            pypi_0                pypi
# scipy                                    1.13.1           py39haf93ffa_0        https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# seaborn-base                             0.13.2           pyhd8ed1ab_3          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# sepp                                     4.5.5            py39hbcbf7aa_3        bioconda
# seqkit                                   2.12.0           he881be0_1            bioconda
# seqtk                                    1.4              he4a0461_2            bioconda
# setuptools                               80.10.2          pypi_0                pypi
# simplejson                               3.20.1           py39h8cd3c5a_0        conda-forge
# six                                      1.17.0           pyhe01879c_1          conda-forge
# sniffio                                  1.3.1            pyhd8ed1ab_1          conda-forge
# spades                                   4.0.0            h6dccd9a_3            bioconda
# spectra                                  0.0.11           pyhd8ed1ab_2          conda-forge
# sqlite                                   3.46.0           h6d4b2fc_0            conda-forge
# sra-tools                                3.1.1            h4304569_2            bioconda
# stack_data                               0.6.3            pyhd8ed1ab_1          conda-forge
# star                                     2.7.11b          h43eeafb_3            bioconda
# statsmodels                              0.14.5           py39h7c0b2d6_0        https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# subread                                  2.0.6            he4a0461_2            bioconda
# suitesparse                              5.10.1           h9e50725_1            conda-forge
# t-coffee                                 12.00.7fb08c2    h26a2512_0            bioconda
# tar                                      1.35             h3b78370_0            conda-forge
# tbb                                      2021.7.0         h924138e_0            conda-forge
# tbl2asn-forever                          25.7.2f          h7b50bb2_6            bioconda
# textwrap3                                0.9.2            py_0                  https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# threadpoolctl                            3.6.0            pypi_0                pypi
# tk                                       8.6.13           noxft_h4845f30_101    conda-forge
# toml                                     0.10.2           pyhd8ed1ab_1          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# tomli                                    2.4.1            pypi_0                pypi
# tornado                                  6.5.2            py39hd399759_0        conda-forge
# tqdm                                     4.67.1           pyhd8ed1ab_1          conda-forge
# traitlets                                5.14.3           pyhd8ed1ab_1          conda-forge
# trimmomatic                              0.40             hdfd78af_0            bioconda
# trnascan-se                              2.0.12           pl5321h7b50bb2_2      bioconda
# typing-extensions                        4.15.0           pypi_0                pypi
# typing_extensions                        4.14.1           pyhe01879c_0          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# tzdata                                   2025.3           pypi_0                pypi
# ucsc-fatotwobit                          472              he8037a5_0            bioconda
# ucsc-twobitinfo                          472              h9b8f530_0            bioconda
# unicodedata2                             16.0.0           py39h8cd3c5a_0        conda-forge
# unicycler                                0.5.1            py39heaaa4ec_2        bioconda
# unzip                                    6.0              hb03c661_4            conda-forge
# urllib3                                  2.6.3            pypi_0                pypi
# varscan                                  2.4.6            hdfd78af_0            bioconda
# vcftools                                 0.1.16           pl5321hdcf5f25_11     bioconda
# verboselogs                              1.7              pyhd8ed1ab_1          conda-forge
# viennarna                                2.7.0            py39pl5321hc9faaad_0  bioconda
# viralverify                              1.1              hdfd78af_0            bioconda
# wcwidth                                  0.2.13           pyhd8ed1ab_1          conda-forge
# wget                                     1.21.4           hda4d442_0            conda-forge
# wheel                                    0.45.1           pyhd8ed1ab_1          conda-forge
# xmltodict                                0.14.2           pyhd8ed1ab_1          conda-forge
# xorg-libice                              1.1.2            hb9d3cd8_0            conda-forge
# xorg-libsm                               1.2.6            he73a12e_0            conda-forge
# xorg-libx11                              1.8.13           he1eb515_0            conda-forge
# xorg-libxau                              1.0.12           hb03c661_1            conda-forge
# xorg-libxdmcp                            1.1.5            hb03c661_1            conda-forge
# xorg-libxext                             1.3.7            hb03c661_0            conda-forge
# xorg-libxfixes                           6.0.2            hb03c661_0            conda-forge
# xorg-libxi                               1.8.2            hb9d3cd8_0            conda-forge
# xorg-libxrender                          0.9.12           hb9d3cd8_0            conda-forge
# xorg-libxtst                             1.2.5            hb9d3cd8_3            conda-forge
# xz                                       5.8.2            ha02ee65_0            conda-forge
# xz-gpl-tools                             5.8.2            ha02ee65_0            conda-forge
# xz-tools                                 5.8.2            hb03c661_0            conda-forge
# yaml                                     0.2.5            h280c20c_3            conda-forge
# zeromq                                   4.3.5            h387f397_9            conda-forge
# zipp                                     3.23.0           pyhd8ed1ab_0          conda-forge
# zlib                                     1.2.13           h4ab18f5_6            conda-forge
# zstandard                                0.23.0           py39hd399759_3        conda-forge
# zstd                                     1.5.6            ha6fb4c9_0            conda-forge

# %%
conda activate IGV && conda list
# Out:
# # packages in environment at /home/suunar/miniforge3/envs/IGV:
# #
# # Name                       Version          Build             Channel
# _openmp_mutex                4.5              20_gnu            conda-forge
# alsa-lib                     1.2.15.3         hb03c661_0        conda-forge
# bzip2                        1.0.8            hda65f42_9        conda-forge
# ca-certificates              2026.2.25        hbd8a1cb_0        conda-forge
# cairo                        1.18.4           he90730b_1        conda-forge
# font-ttf-dejavu-sans-mono    2.37             hab24e00_0        conda-forge
# font-ttf-inconsolata         3.000            h77eed37_0        conda-forge
# font-ttf-source-code-pro     2.038            h77eed37_0        conda-forge
# font-ttf-ubuntu              0.83             h77eed37_3        conda-forge
# fontconfig                   2.17.1           h27c8c51_0        conda-forge
# fonts-conda-ecosystem        1                0                 conda-forge
# fonts-conda-forge            1                hc364b38_1        conda-forge
# giflib                       5.2.2            hd590300_0        conda-forge
# graphite2                    1.3.14           hecca717_2        conda-forge
# harfbuzz                     13.2.1           h6083320_0        conda-forge
# icu                          78.3             h33c6efd_0        conda-forge
# igv                          2.19.7           h33ea123_0        bioconda
# keyutils                     1.6.3            hb9d3cd8_0        conda-forge
# krb5                         1.22.2           ha1258a1_0        conda-forge
# lcms2                        2.18             h0c24ade_0        conda-forge
# lerc                         4.1.0            hdb68285_0        conda-forge
# libcups                      2.3.3            h7a8fb5f_6        conda-forge
# libdeflate                   1.25             h17f619e_0        conda-forge
# libedit                      3.1.20250104     pl5321h7949ede_0  conda-forge
# libexpat                     2.7.5            hecca717_0        conda-forge
# libffi                       3.5.2            h3435931_0        conda-forge
# libfreetype                  2.14.3           ha770c72_0        conda-forge
# libfreetype6                 2.14.3           h73754d4_0        conda-forge
# libgcc                       15.2.0           he0feb66_18       conda-forge
# libgcc-ng                    15.2.0           h69a702a_18       conda-forge
# libglib                      2.86.4           h6548e54_1        conda-forge
# libgomp                      15.2.0           he0feb66_18       conda-forge
# libiconv                     1.18             h3b78370_2        conda-forge
# libjpeg-turbo                3.1.2            hb03c661_0        conda-forge
# liblzma                      5.8.2            hb03c661_0        conda-forge
# libpng                       1.6.56           h421ea60_0        conda-forge
# libstdcxx                    15.2.0           h934c35e_18       conda-forge
# libtiff                      4.7.1            h9d88235_1        conda-forge
# libuuid                      2.41.3           h5347b49_0        conda-forge
# libwebp-base                 1.6.0            hd42ef1d_0        conda-forge
# libxcb                       1.17.0           h8a09558_0        conda-forge
# libzlib                      1.3.2            h25fd6f3_2        conda-forge
# ncurses                      6.5              h2d0b736_3        conda-forge
# openjdk                      21.0.10          ha668962_0        conda-forge
# openssl                      3.6.1            h35e630c_1        conda-forge
# pcre2                        10.47            haa7fec5_0        conda-forge
# pixman                       0.46.4           h54a6638_1        conda-forge
# pthread-stubs                0.4              hb9d3cd8_1002     conda-forge
# xorg-libice                  1.1.2            hb9d3cd8_0        conda-forge
# xorg-libsm                   1.2.6            he73a12e_0        conda-forge
# xorg-libx11                  1.8.13           he1eb515_0        conda-forge
# xorg-libxau                  1.0.12           hb03c661_1        conda-forge
# xorg-libxdmcp                1.1.5            hb03c661_1        conda-forge
# xorg-libxext                 1.3.7            hb03c661_0        conda-forge
# xorg-libxfixes               6.0.2            hb03c661_0        conda-forge
# xorg-libxi                   1.8.2            hb9d3cd8_0        conda-forge
# xorg-libxrandr               1.5.5            hb03c661_0        conda-forge
# xorg-libxrender              0.9.12           hb9d3cd8_0        conda-forge
# xorg-libxt                   1.3.1            hb9d3cd8_0        conda-forge
# xorg-libxtst                 1.2.5            hb9d3cd8_3        conda-forge
# zstd                         1.5.7            hb78ec9c_6        conda-forge

# %%
conda activate SPAdes && conda list
# Out:
# # packages in environment at /home/suunar/miniforge3/envs/SPAdes:
# #
# # Name                                   Version          Build                 Channel
# _openmp_mutex                            4.5              20_gnu                https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# alsa-lib                                 1.2.15.3         hb03c661_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# aragorn                                  1.2.41           h7b50bb2_5            bioconda
# argtable2                                2.13             hd590300_1004         conda-forge
# barrnap                                  0.9              hdfd78af_4            bioconda
# bedtools                                 2.31.1           hf5e1c6e_2            bioconda
# blast                                    2.15.0           pl5321h6f7f691_1      bioconda
# blast-legacy                             2.2.26           hf7ff83a_5            bioconda
# bzip2                                    1.0.8            hda65f42_9            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# c-ares                                   1.34.6           hb03c661_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# ca-certificates                          2026.2.25        hbd8a1cb_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# cairo                                    1.12.18          6                     https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# clustalo                                 1.2.4            h503566f_10           bioconda
# clustalw                                 2.1              h9948957_12           bioconda
# curl                                     7.26.0           1                     https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# entrez-direct                            24.0             he881be0_0            bioconda
# expat                                    2.7.4            hecca717_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# font-ttf-dejavu-sans-mono                2.37             hab24e00_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# font-ttf-inconsolata                     3.000            h77eed37_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# font-ttf-source-code-pro                 2.038            h77eed37_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# font-ttf-ubuntu                          0.83             h77eed37_3            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# fontconfig                               2.11.1           6                     https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# fonts-conda-ecosystem                    1                0                     https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# fonts-conda-forge                        1                hc364b38_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# freetype                                 2.5.5            2                     https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# gawk                                     5.3.1            hcd3d067_0            conda-forge
# giflib                                   5.2.2            hd590300_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# glib                                     2.80.2           hf974151_0            conda-forge
# glib-tools                               2.80.2           hb6ce0ca_0            conda-forge
# gmp                                      6.3.0            hac33072_2            conda-forge
# gnutls                                   3.8.11           h18acefa_1            conda-forge
# graphite2                                1.3.14           hecca717_2            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# gsl                                      2.7              he838d99_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# harfbuzz                                 0.9.39           1                     https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# hmmer                                    3.4              hb6cb901_4            bioconda
# icu                                      78.3             h33c6efd_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# infernal                                 1.1.4            h779adbc_0            bioconda
# jpeg                                     9e               h166bdaf_2            conda-forge
# keyutils                                 1.6.3            hb9d3cd8_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# krb5                                     1.22.2           ha1258a1_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# lcms2                                    2.12             hddcbb42_0            conda-forge
# ld_impl_linux-64                         2.45.1           bootstrap_ha15bf96_2  conda-forge
# lerc                                     4.1.0            hdb68285_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libasprintf                              0.25.1           h3f43e3d_1            conda-forge
# libblas                                  3.11.0           6_h4a7cf45_openblas   https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libcblas                                 3.11.0           6_h0358290_openblas   https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libcups                                  2.4.15           hbe4054b_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# libcurl                                  8.16.0           heebcbe5_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# libdb                                    6.2.32           h9c3ff4c_0            conda-forge
# libdeflate                               1.25             h17f619e_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libedit                                  3.1.20250104     pl5321h7949ede_0      https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libev                                    4.33             hd590300_2            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libexpat                                 2.7.4            hecca717_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libffi                                   3.5.2            h3435931_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libgcc                                   15.2.0           he0feb66_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libgcc-ng                                15.2.0           h69a702a_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libgettextpo                             0.25.1           h3f43e3d_1            conda-forge
# libgfortran                              15.2.0           h69a702a_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libgfortran-ng                           15.2.0           h69a702a_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libgfortran5                             15.2.0           h68bc16d_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libglib                                  2.80.2           hf974151_0            conda-forge
# libgomp                                  15.2.0           he0feb66_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libiconv                                 1.18             h3b78370_2            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libidn11                                 1.34             h1cef754_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libidn2                                  2.3.8            hfac485b_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libjpeg-turbo                            2.1.4            h166bdaf_0            conda-forge
# liblzma                                  5.8.2            hb03c661_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# liblzma-devel                            5.8.2            hb03c661_0            conda-forge
# libmpdec                                 4.0.0            hb03c661_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libnghttp2                               1.58.0           h47da74e_1            conda-forge
# libopenblas                              0.3.32           pthreads_h94d23a6_0   https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libpng                                   1.6.43           h2797004_0            conda-forge
# libsqlite                                3.46.0           hde9e2c9_0            conda-forge
# libssh2                                  1.11.1           h251f7ec_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# libstdcxx                                15.2.0           h934c35e_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libstdcxx-ng                             15.2.0           hdf11a46_18           https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libtasn1                                 4.21.0           hb03c661_0            conda-forge
# libtiff                                  4.2.0            hf544144_3            conda-forge
# libunistring                             0.9.10           h7f98852_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libuuid                                  1.41.5           h5eee18b_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# libwebp-base                             1.6.0            hd42ef1d_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libxcb                                   1.17.0           h8a09558_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# libxcrypt                                4.4.36           hd590300_1            conda-forge
# libxml2                                  2.9.4            0                     https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# libzlib                                  1.2.13           h4ab18f5_6            conda-forge
# mafft                                    7.526            h4bc722e_0            conda-forge
# minced                                   0.4.2            hdfd78af_1            bioconda
# mpfr                                     4.2.2            he0a73b1_0            conda-forge
# mpi                                      1.0              openmpi               https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# muscle                                   5.3              h9948957_3            bioconda
# ncbi-vdb                                 3.4.1            hd63eeec_0            bioconda
# ncurses                                  6.5              h2d0b736_3            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# nettle                                   3.10.1           h4a9d5aa_0            conda-forge
# openjdk                                  11.0.1           h516909a_1016         conda-forge
# openmpi                                  4.1.6            hc5af2df_101          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# openssl                                  3.6.1            h35e630c_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# p11-kit                                  0.26.2           h3435931_0            conda-forge
# paml                                     4.10.10          h7b50bb2_0            bioconda
# parallel                                 20260122         ha770c72_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# pcre                                     8.45             h9c3ff4c_0            conda-forge
# pcre2                                    10.43            hcad00b1_0            conda-forge
# perl                                     5.32.1           7_hd590300_perl5      conda-forge
# perl-algorithm-diff                      1.201            pl5321hd8ed1ab_0      conda-forge
# perl-archive-tar                         3.04             pl5321hdfd78af_0      bioconda
# perl-b-cow                               0.007            pl5321hb9d3cd8_1      conda-forge
# perl-base                                2.23             pl5321hd8ed1ab_0      conda-forge
# perl-bio-asn1-entrezgene                 1.73             pl5321hdfd78af_3      bioconda
# perl-bio-coordinate                      1.007001         pl5321hdfd78af_3      bioconda
# perl-bio-featureio                       1.6.905          pl5321hdfd78af_4      bioconda
# perl-bio-samtools                        1.43             pl5321he4a0461_4      bioconda
# perl-bio-searchio-hmmer                  1.7.3            pl5321hdfd78af_0      bioconda
# perl-bio-tools-phylo-paml                1.7.3            pl5321hdfd78af_3      bioconda
# perl-bio-tools-run-alignment-clustalw    1.7.4            pl5321hdfd78af_3      bioconda
# perl-bio-tools-run-alignment-tcoffee     1.7.4            pl5321hdfd78af_5      bioconda
# perl-bioperl                             1.7.8            hdfd78af_1            bioconda
# perl-bioperl-core                        1.7.8            pl5321hdfd78af_1      bioconda
# perl-bioperl-run                         1.007003         pl5321hdfd78af_0      bioconda
# perl-business-isbn                       3.007            pl5321hd8ed1ab_0      conda-forge
# perl-business-isbn-data                  20210112.006     pl5321hd8ed1ab_0      conda-forge
# perl-carp                                1.50             pl5321hd8ed1ab_0      conda-forge
# perl-class-data-inheritable              0.09             pl5321ha770c72_0      conda-forge
# perl-clone                               0.46             pl5321hb9d3cd8_1      conda-forge
# perl-common-sense                        3.75             pl5321hd8ed1ab_0      conda-forge
# perl-compress-raw-bzip2                  2.214            pl5321hda65f42_0      conda-forge
# perl-compress-raw-zlib                   2.214            pl5321h4dac143_0      conda-forge
# perl-constant                            1.33             pl5321hd8ed1ab_0      conda-forge
# perl-data-dump                           1.25             pl5321h7b50bb2_2      bioconda
# perl-data-dumper                         2.183            pl5321hb9d3cd8_1      conda-forge
# perl-db_file                             1.858            pl5321hb9d3cd8_0      conda-forge
# perl-devel-stacktrace                    2.04             pl5321h296ab09_0      conda-forge
# perl-digest-hmac                         1.05             pl5321hdfd78af_0      bioconda
# perl-digest-md5                          2.59             pl5321hb9d3cd8_3      conda-forge
# perl-encode                              3.21             pl5321hb9d3cd8_1      conda-forge
# perl-encode-locale                       1.05             pl5321hdfd78af_7      bioconda
# perl-exception-class                     1.45             pl5321ha770c72_0      conda-forge
# perl-exporter                            5.74             pl5321hd8ed1ab_0      conda-forge
# perl-exporter-tiny                       1.002002         pl5321hd8ed1ab_0      conda-forge
# perl-extutils-makemaker                  7.70             pl5321hd8ed1ab_0      conda-forge
# perl-file-listing                        6.16             pl5321hdfd78af_0      bioconda
# perl-file-path                           2.18             pl5321hd8ed1ab_0      conda-forge
# perl-file-slurper                        0.014            pl5321hdfd78af_0      bioconda
# perl-file-sort                           1.01             pl5321hdfd78af_3      bioconda
# perl-file-spec                           3.48_01          pl5321hdfd78af_2      bioconda
# perl-file-temp                           0.2304           pl5321hd8ed1ab_0      conda-forge
# perl-getopt-long                         2.58             pl5321hdfd78af_0      bioconda
# perl-html-parser                         3.81             pl5321h4ac6f70_1      bioconda
# perl-html-tagset                         3.24             pl5321hdfd78af_0      bioconda
# perl-http-cookiejar-lwp                  0.014            pl5321hdfd78af_0      bioconda
# perl-http-cookies                        6.11             pl5321hdfd78af_0      bioconda
# perl-http-daemon                         6.16             pl5321hdfd78af_0      bioconda
# perl-http-date                           6.06             pl5321hdfd78af_0      bioconda
# perl-http-message                        7.01             pl5321hdfd78af_0      bioconda
# perl-http-negotiate                      6.01             pl5321hdfd78af_4      bioconda
# perl-inc-latest                          0.500            pl5321ha770c72_0      conda-forge
# perl-io-compress                         2.216            pl5321h503566f_0      bioconda
# perl-io-html                             1.004            pl5321hdfd78af_0      bioconda
# perl-io-socket-ssl                       2.075            pl5321hd8ed1ab_0      conda-forge
# perl-io-string                           1.08             pl5321hdfd78af_4      bioconda
# perl-io-tty                              1.23             pl5321hb03c661_0      conda-forge
# perl-io-zlib                             1.15             pl5321hdfd78af_1      bioconda
# perl-ipc-run                             20250809.0       pl5321hdfd78af_0      bioconda
# perl-json                                4.11             pl5321hdfd78af_0      bioconda
# perl-json-xs                             4.04             pl5321h9948957_0      bioconda
# perl-libwww-perl                         6.81             pl5321hdfd78af_0      bioconda
# perl-libxml-perl                         0.08             pl5321hdfd78af_3      bioconda
# perl-list-moreutils                      0.430            pl5321hdfd78af_0      bioconda
# perl-list-moreutils-xs                   0.430            pl5321h7b50bb2_5      bioconda
# perl-lwp-mediatypes                      6.04             pl5321hdfd78af_1      bioconda
# perl-lwp-protocol-https                  6.15             pl5321hdfd78af_0      bioconda
# perl-mime-base64                         3.16             pl5321hb9d3cd8_3      conda-forge
# perl-module-build                        0.4234           pl5321ha770c72_1      conda-forge
# perl-module-load                         0.34             pl5321hdfd78af_0      bioconda
# perl-mozilla-ca                          20250602         pl5321hdfd78af_0      bioconda
# perl-net-http                            6.24             pl5321hdfd78af_0      bioconda
# perl-net-ssleay                          1.92             pl5321hf14f497_1      conda-forge
# perl-ntlm                                1.09             pl5321hdfd78af_5      bioconda
# perl-parent                              0.243            pl5321hd8ed1ab_0      conda-forge
# perl-pathtools                           3.75             pl5321hb9d3cd8_2      conda-forge
# perl-scalar-list-utils                   1.70             pl5321hb03c661_0      conda-forge
# perl-socket                              2.027            pl5321h5c03b87_6      bioconda
# perl-storable                            3.15             pl5321hb9d3cd8_2      conda-forge
# perl-sub-uplevel                         0.2800           pl5321hb9d3cd8_0      conda-forge
# perl-test-deep                           1.130            pl5321hd8ed1ab_0      conda-forge
# perl-test-differences                    0.72             pl5321ha770c72_0      conda-forge
# perl-test-exception                      0.43             pl5321hd8ed1ab_0      conda-forge
# perl-test-fatal                          0.016            pl5321hdfd78af_0      bioconda
# perl-test-most                           0.38             pl5321hdfd78af_0      bioconda
# perl-test-needs                          0.002009         pl5321hd8ed1ab_0      conda-forge
# perl-test-requiresinternet               0.05             pl5321hdfd78af_1      bioconda
# perl-test-warn                           0.37             pl5321hd8ed1ab_0      conda-forge
# perl-test-warnings                       0.031            pl5321ha770c72_0      conda-forge
# perl-text-diff                           1.45             pl5321hd8ed1ab_0      conda-forge
# perl-threaded                            5.32.1           hdfd78af_1            bioconda
# perl-time-local                          1.35             pl5321hdfd78af_0      bioconda
# perl-timedate                            2.33             pl5321hdfd78af_2      bioconda
# perl-tree-dag_node                       1.35             pl5321hdfd78af_0      bioconda
# perl-try-tiny                            0.32             pl5321ha770c72_1      conda-forge
# perl-types-serialiser                    1.01             pl5321hdfd78af_0      bioconda
# perl-uri                                 5.34             pl5321ha770c72_0      conda-forge
# perl-url-encode                          0.03             pl5321h9ee0642_1      bioconda
# perl-www-robotrules                      6.02             pl5321hdfd78af_4      bioconda
# perl-xml-dom                             1.46             pl5321hdfd78af_1      bioconda
# perl-xml-dom-xpath                       0.14             pl5321hdfd78af_2      bioconda
# perl-xml-namespacesupport                1.12             pl5321hd8ed1ab_0      conda-forge
# perl-xml-parser                          2.44_01          pl5340hf309648_0      https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# perl-xml-regexp                          0.04             pl5321hdfd78af_3      bioconda
# perl-xml-sax                             1.02             pl5321hd8ed1ab_0      conda-forge
# perl-xml-sax-base                        1.09             pl5321hd8ed1ab_0      conda-forge
# perl-xml-sax-expat                       0.51             pl5321hd8ed1ab_0      conda-forge
# perl-xml-simple                          2.25             pl5321hdfd78af_2      bioconda
# perl-xml-xpathengine                     0.14             pl5321hdfd78af_3      bioconda
# pip                                      26.0.1           pyh145f28c_0          https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# pixman                                   0.32.6           0                     conda-forge
# poa                                      2.0              h7b50bb2_6            bioconda
# prodigal                                 2.6.3            h7b50bb2_10           bioconda
# prokka                                   1.14.6           pl5321hdfd78af_5      bioconda
# pthread-stubs                            0.4              hb9d3cd8_1002         https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# python                                   3.14.2           h90eec9f_101_cp314    https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# python_abi                               3.14             8_cp314               https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# readline                                 8.3              h853b02a_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# spades                                   4.0.0            h6dccd9a_3            bioconda
# sqlite                                   3.51.1           he0a8d7e_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# t-coffee                                 12.00.7fb08c2    h26a2512_0            bioconda
# tbl2asn-forever                          25.7.2f          h7b50bb2_6            bioconda
# tk                                       8.6.15           h54e0aa7_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# tzdata                                   2025c            hc9c84f9_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# viennarna                                2.4.7            py27_2                bioconda
# wget                                     1.21.4           hda4d442_0            conda-forge
# xorg-libice                              1.1.2            hb9d3cd8_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libsm                               1.2.6            h9b100fa_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# xorg-libx11                              1.8.13           he1eb515_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxau                              1.0.12           hb03c661_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxdmcp                            1.1.5            hb03c661_1            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxext                             1.3.7            hb03c661_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxfixes                           6.0.2            hb03c661_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxi                               1.8.2            hb9d3cd8_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxrandr                           1.5.5            hb03c661_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxrender                          0.9.12           hb9d3cd8_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxt                               1.3.1            hb9d3cd8_0            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-libxtst                             1.2.5            hb9d3cd8_3            https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/conda-forge
# xorg-xorgproto                           2024.1           hb9d3cd8_1            conda-forge
# xz                                       5.8.2            ha02ee65_0            conda-forge
# xz-gpl-tools                             5.8.2            ha02ee65_0            conda-forge
# xz-tools                                 5.8.2            hb03c661_0            conda-forge
# zlib                                     1.2.13           h4ab18f5_6            conda-forge
# zstd                                     1.5.6            ha6fb4c9_0            conda-forge

# %% [markdown]
# # Первичная обработка ридов

# %%
conda activate biolab

mkdir -p RawData && cd RawData # Папка для ридов и референсных данных

# Загрузка референсного генома и референсной аннотации

wget https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/005/845/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz \
&& wget https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/005/845/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_cds_from_genomic.fna.gz \
&& wget https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/005/845/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.fna.gz

gunzip GCF_000005845.2_ASM584v2_cds_from_genomic.fna.gz && gunzip GCF_000005845.2_ASM584v2_genomic.gff.gz && gunzip GCF_000005845.2_ASM584v2_genomic.fna.gz

# Загрузка ридов через интерфейс гугл по общему пути /home/suunar/Downloads

# Перенос ридов в рабочую директорию

cd ~ && mv ./Downloads/amp_res_1.fastq.zip ./projects/Helloworld/TASK2/RawData \
&& mv mv ./Downloads/amp_res_2.fastq.zip ./projects/Helloworld/TASK2/RawData \
&& cd projects/Helloworld/TASK2/RawData

# Распаковка ридов

unzip amp_res_1.fastq.zip && unzip amp_res_2.fastq.zip

# Удаляем уже ненужные архивы ридов

rm amp_res_1.fastq.zip && rm amp_res_2.fastq.zip

# Контроль качества ридов fastqc

cd .. && mkdir -p FASTQCrep

cd FASTQCrep && mkdir -p Forw && mkdir -p Backw

fastqc -o Forw ../RawData/amp_res_1.fastq && fastqc -o Backw ../RawData/amp_res_2.fastq

# В целом, все не плохо, но нужно слегка подрезать концы ридов

cd .. && mkdir -p Trimmed

cd Trimmed && mkdir -p Paired && mkdir -p Unpaired && cd ..

trimmomatic PE ./RawData/amp_res_1.fastq ./RawData/amp_res_2.fastq \
            ./Trimmed/Paired/amp_res_1.fastq ./Trimmed/Unpaired/amp_res_1.fastq \
            ./Trimmed/Paired/amp_res_2.fastq ./Trimmed/Unpaired/amp_res_2.fastq \
            LEADING:20 TRAILING:20 SLIDINGWINDOW:10:20 MINLEN:20

# Получаем парные риды по пути ./Trimmed/Paired и непарные риды по пути ./Trimmed/Unpaired

# Теперь мы готовы к выравниванию на референс

# %% [markdown]
# # Маппинг

# %%
# Индексирование

mkdir -p Index

bwa index ./RawData/GCF_000005845.2_ASM584v2_cds_from_genomic.fna

# Перенос файлов в созданную директорию вручную, потому что bwa дегенерат

mv ./RawData/GCF_000005845.2_ASM584v2_genomic.fna.amb ./Index && \
mv ./RawData/GCF_000005845.2_ASM584v2_genomic.fna.ann ./Index && \
mv ./RawData/GCF_000005845.2_ASM584v2_genomic.fna.bwt ./Index && \
mv ./RawData/GCF_000005845.2_ASM584v2_genomic.fna.pac ./Index && \
mv ./RawData/GCF_000005845.2_ASM584v2_genomic.fna.sa ./Index 

# Выравнивание

bwa mem -t 6 -M Index/GCF_000005845.2_ASM584v2_genomic.fna ./Trimmed/Paired/amp_res_1.fastq ./Trimmed/Paired/amp_res_2.fastq > aligned.sam

mkdir -p SAM && mv aligned.sam SAM # Файл выравнивания в отдельную папку для красоты

samtools view -S -b aligned.sam > aligned.bam # Бинаризация sam-файла в bam-файл

samtools flagstat aligned.bam # Первичная статистика по выравниванию (вывод ниже)

samtools sort aligned.bam -o aligned_sorted.bam # Сортировка

samtools index aligned_sorted.bam # Повторное индексирование

# В папке SAM должен создаться файл aligned_sorted.bam.bai, который будет использоваться в ближайшем будущем

# %% [markdown]
# ```text
# 892776 + 0 in total (QC-passed reads + QC-failed reads)
# 892518 + 0 primary
# 258 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 891649 + 0 mapped (99.87% : N/A)
# 891391 + 0 primary mapped (99.87% : N/A)
# 892518 + 0 paired in sequencing
# 446259 + 0 read1
# 446259 + 0 read2
# 888566 + 0 properly paired (99.56% : N/A)
# 890412 + 0 with itself and mate mapped
# 979 + 0 singletons (0.11% : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)

# %% [markdown]
# # Оценка мутаций и визуализация

# %%
# Просмотр результатов выравнивания через интерфейс 

# Программа работает только с впн из-за переброса трафика через google((

conda activate IGV

igv

# После небольшого обзора выходим из программы на CTRL + C

conda activate biolab

conda install -c bioconda varscan

# Фиксируем количество снипов

samtools mpileup -f ./Index/GCF_000005845.2_ASM584v2_genomic.fna ./SAM/aligned_sorted.bam >  my.mpileup

# Получаем результаты в VCF файл

# В качестве фильтра пробуем значения 70%, 80%, 90% и 95% для необходимого кол-ва ридов для подтверждения мутации

mkdir -p VCF && cd VCF 

varscan mpileup2snp ../my.mpileup --min-var-freq 0.7 --variants --output-vcf 1 > VarScan_70_results.vcf # Зарегистрировано 6 снипов и 3 indel-а

varscan mpileup2snp ../my.mpileup --min-var-freq 0.8 --variants --output-vcf 1 > VarScan_80_results.vcf # Зарегистрировано 6 снипов и 3 indel-а

varscan mpileup2snp ../my.mpileup --min-var-freq 0.9 --variants --output-vcf 1 > VarScan_90_results.vcf # Зарегистрировано 6 снипов и 3 indel-а

varscan mpileup2snp ../my.mpileup --min-var-freq 0.95 --variants --output-vcf 1 > VarScan_95_results.vcf # Зарегистрировано 6 снипов и 0 indel-ов

# %% [markdown]
# # Снип 1: Замена A -> G peptidoglycan DD-transpeptidase FtsI

# %% [markdown]
# ```text
# type: gene
# ID: gene-b0084
# Dbxref: ASAP:ABE-0000309,ECOCYC:EG10341,GeneID:944799
# Name: ftsI
# gbkey: Gene
# gene: ftsI
# gene_biotype: protein_coding
# gene_synonym: ECK0085,pbpB,sep
# locus_tag: b0084
# ---------------------------
# type: CDS
# ID: cds-NP_414626.1
# Parent: gene-b0084
# Dbxref: UniProtKB/Swiss-Prot:P0AD68,GenBank:NP_414626.1,ASAP:ABE-0000309,ECOCYC:EG10341,GeneID:944799
# Name: NP_414626.1
# gbkey: CDS
# gene: ftsI
# locus_tag: b0084
# product: peptidoglycan DD-transpeptidase FtsI
# protein_id: NP_414626.1
# transl_table: 11
#
# type: region
# ID: NC_000913.3:1..4641652
# Dbxref: taxon:511145
# Is_circular: true
# Name: ANONYMOUS
# gbkey: Src
# genome: chromosome
# mol_type: genomic DNA
# strain: K-12
# substrain: MG1655
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Снип 2: Замена Q -> Q в multidrug efflux pump RND permease AcrB

# %% [markdown]
# ```text
# type: gene
# ID: gene-b0462
# Dbxref: ASAP:ABE-0001601,ECOCYC:EG11704,GeneID:945108
# Name: acrB
# gbkey: Gene
# gene: acrB
# gene_biotype: protein_coding
# gene_synonym: acrE,ECK0456
# locus_tag: b0462
# ---------------------------
# type: CDS
# ID: cds-NP_414995.1
# Parent: gene-b0462
# Dbxref: UniProtKB/Swiss-Prot:P31224,GenBank:NP_414995.1,ASAP:ABE-0001601,ECOCYC:EG11704,GeneID:945108
# Name: NP_414995.1
# gbkey: CDS
# gene: acrB
# locus_tag: b0462
# product: multidrug efflux pump RND permease AcrB
# protein_id: NP_414995.1
# transl_table: 11
#
# type: region
# ID: NC_000913.3:1..4641652
# Dbxref: taxon:511145
# Is_circular: true
# Name: ANONYMOUS
# gbkey: Src
# genome: chromosome
# mol_type: genomic DNA
# strain: K-12
# substrain: MG1655
# ```

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Снип 3: Замена в small RNA RybA

# %% [markdown]
# ```text
# type: gene
# ID: gene-b4416
# Dbxref: ASAP:ABE-0047240,ECOCYC:G0-8881,GeneID:2847681
# Name: rybA
# gbkey: Gene
# gene: rybA
# gene_biotype: ncRNA
# gene_synonym: ECK0806
# locus_tag: b4416
#
# type: ncRNA
# ID: rna-b4416
# Parent: gene-b4416
# Dbxref: ASAP:ABE-0047240,ECOCYC:G0-8881,GeneID:2847681
# gbkey: ncRNA
# gene: rybA
# locus_tag: b4416
# product: small RNA RybA
# ---------------------------
# type: exon
# ID: exon-b4416-1
# Parent: rna-b4416
# Dbxref: ASAP:ABE-0047240,ECOCYC:G0-8881,GeneID:2847681
# gbkey: ncRNA
# gene: rybA
# locus_tag: b4416
# product: small RNA RybA
#
# type: region
# ID: NC_000913.3:1..4641652
# Dbxref: taxon:511145
# Is_circular: true
# Name: ANONYMOUS
# gbkey: Src
# genome: chromosome
# mol_type: genomic DNA
# strain: K-12
# substrain: MG1655
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Снип 4: Замена G -> D в Mn(2( )) exporter (mntP)

# %% [markdown]
# ```text
# type: gene
# ID: gene-b1821
# Dbxref: ASAP:ABE-0006065,ECOCYC:G6999,GeneID:946341
# Name: mntP
# gbkey: Gene
# gene: mntP
# gene_biotype: protein_coding
# gene_synonym: ECK1819,yebN
# locus_tag: b1821
# ---------------------------
# type: CDS
# ID: cds-NP_416335.4
# Parent: gene-b1821
# Dbxref: UniProtKB/Swiss-Prot:P76264,GenBank:NP_416335.4,ASAP:ABE-0006065,ECOCYC:G6999,GeneID:946341
# Name: NP_416335.4
# gbkey: CDS
# gene: mntP
# locus_tag: b1821
# product: Mn(2( )) exporter
# protein_id: NP_416335.4
# transl_table: 11
#
# type: region
# ID: NC_000913.3:1..4641652
# Dbxref: taxon:511145
# Is_circular: true
# Name: ANONYMOUS
# gbkey: Src
# genome: chromosome
# mol_type: genomic DNA
# strain: K-12
# substrain: MG1655
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Снип 5: Замена V -> S в sensor histidine kinase EnvZ

# %% [markdown]
# ```text
# Возможно, сместился активный центр
#
# type: gene
# ID: gene-b3404
# Dbxref: ASAP:ABE-0011108,ECOCYC:EG10269,GeneID:947272
# Name: envZ
# gbkey: Gene
# gene: envZ
# gene_biotype: protein_coding
# gene_synonym: ECK3391,ompB,perA,tpo
# locus_tag: b3404
# ---------------------------
# type: CDS
# ID: cds-NP_417863.1
# Parent: gene-b3404
# Dbxref: UniProtKB/Swiss-Prot:P0AEJ4,GenBank:NP_417863.1,ASAP:ABE-0011108,ECOCYC:EG10269,GeneID:947272
# Name: NP_417863.1
# gbkey: CDS
# gene: envZ
# locus_tag: b3404
# product: sensor histidine kinase EnvZ
# protein_id: NP_417863.1
# transl_table: 11
#
# type: region
# ID: NC_000913.3:1..4641652
# Dbxref: taxon:511145
# Is_circular: true
# Name: ANONYMOUS
# gbkey: Src
# genome: chromosome
# mol_type: genomic DNA
# strain: K-12
# substrain: MG1655
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Снип 6: Замена A -> A в ribosome small subunit-dependent GTPase A

# %% [markdown]
# ```text
# type: gene
# ID: gene-b4161
# Dbxref: ASAP:ABE-0013626,ECOCYC:G7841,GeneID:948674
# Name: rsgA
# gbkey: Gene
# gene: rsgA
# gene_biotype: protein_coding
# gene_synonym: ECK4157,yjeQ
# locus_tag: b4161
# ---------------------------
# type: CDS
# ID: cds-NP_418585.4
# Parent: gene-b4161
# Dbxref: UniProtKB/Swiss-Prot:P39286,GenBank:NP_418585.4,ASAP:ABE-0013626,ECOCYC:G7841,GeneID:948674
# Name: NP_418585.4
# gbkey: CDS
# gene: rsgA
# locus_tag: b4161
# product: ribosome small subunit-dependent GTPase A
# protein_id: NP_418585.4
# transl_table: 11
#
# type: region
# ID: NC_000913.3:1..4641652
# Dbxref: taxon:511145
# Is_circular: true
# Name: ANONYMOUS
# gbkey: Src
# genome: chromosome
# mol_type: genomic DNA
# strain: K-12
# substrain: MG1655
#
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Аннотирование снипов

# %%
conda create -n SNPeff -c bioconda snpeff -y && conda activate SNPeff

snpEff -version 

# Консоль: SnpEff  5.4c    2026-02-23

# Поиск файла конфигурации SnpEff

find $CONDA_PREFIX -type f -name "snpEff.config" 2>/dev/null

# Консоль: /home/suunar/miniforge3/envs/SNPeff/share/snpeff-5.4.0c-0/snpEff.config

cd /home/suunar/miniforge3/envs/SNPeff/share/snpeff-5.4.0c-0

# Создание датабазы в файле конфигурации (добавляется в последнюю строчку)

echo "ecoli_k12_mg1655.genome : ecoli_k12_mg1655" >> snpEff.config

mkdir -p data/ecoli_k12_mg1655

cp /home/suunar/projects/Helloworld/TASK2/RawData/GCF_000005845.2_ASM584v2_genomic.gbff data/ecoli_k12_mg1655/genes.gbk

# Сборка датабазы

snpEff build -genbank -v ecoli_k12_mg1655

# Аннотация снипов по только что созданной датабазе

cd /home/suunar/projects/Helloworld/TASK2 # Переход в рабочую директорию

snpEff ann ecoli_k12_mg1655 ./VCF/VarScan_90_results.vcf > ./VCF/VarScan_90_results_annotated.vcf

# %% [markdown]
# # Результаты аннотации

# %% [markdown]
# ```text
#
# №           Annotation         Gene     HGVS       Impact     Position                Product
#
# SNP1 |    missense_variant   | ftsI | Ala544Gly | MODERATE |  544/588  | peptidoglycan DD-transpeptidase FtsI
#
# SNP2 |    missense_variant   | acrB | Gln569Leu | MODERATE |  569/1049 | multidrug efflux pump RND permease AcrB
#
# SNP3 | upstream_gene_variant | glnH |     -     | MODIFIER |     -     | ncRNA
#
# SNP4 |    missense_variant   | mntP | Gly25Asp  | MODERATE |  25/188   | Mn(2(+)) exporter
#
# SNP5 |    missense_variant   | envZ | Val241Gly | MODERATE |  241/450  | sensor histidine kinase EnvZ
#
# SNP6 |  synonymous_variant   | rsgA | Ala252Ala |   LOW    |  252/350  | ribosome small subunit-dependent GTPase A
# ```

# %% [markdown]
# ```text
# если что, всю таблицу печатал руками (((
# ```
